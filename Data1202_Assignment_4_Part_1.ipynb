# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read csv file
df_youtube= pd.read_csv("youtube_dataset.csv",sep=",", encoding='ISO-8859-1')
print("done")
# Out:
# done

# %%
df_youtube.head(10)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# 5   1553043047-5143  https://socialblade.com/youtube/top/5000/mosts...
# 6   1553043043-5142  https://socialblade.com/youtube/top/5000/mosts...
# 7   1553043039-5141  https://socialblade.com/youtube/top/5000/mosts...
# 8   1553043035-5140  https://socialblade.com/youtube/top/5000/mosts...
# 9   1553043027-5138  https://socialblade.com/youtube/top/5000/mosts...
#
#                        userID  \
# 0                   PewDiePie
# 1                    T-Series
# 2                      Gaming
# 3              YouTube Movies
# ...

# %%
# Top 1000 Youtube Channel with most no. of Sucscribers
top_1000_youtubers=df_youtube.head(1000)

# %%
#Show graphs withint Python notebook
# %matplotlib inline

# %%
# Use regular matplotlib function to display a barplot of distribution of channels
top_1000_youtubers.groupby(['channeltype'])['userID'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='channeltype'>

# %%
# Use regular matplotlib function to display a barplot of youtubers with grouped into grades
top_1000_youtubers.groupby(['grade'])['userID'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='grade'>
